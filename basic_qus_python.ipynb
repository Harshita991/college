# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita991/college/blob/master/basic_qus_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Write a Python program to declare a variable and print its value.

a = 10
print("value of a =",a)
# Out:
# value of a = 10

# %%
# 2.a  Write a Python program to take an integer input from the user and display it
num = int(input("Enter a number: "))
print("You enter:", num)
# Out:
# Enter a number: 10
# You enter: 10

# %%
# 2 b Write a Python program to take an integer flot from the user and display it.

num_int = int(input("Enter an integer: "))
num_float = float(input("Enter a float number: "))

print("Integer value:", num_int)
print("Float value:", num_float)
# Out:
# Enter an integer: 20
# Enter a float number: 23.66
# Integer value: 20
# Float value: 23.66

# %%
# 2 c Write a Python program to take an integer true and false from the user and display it.

# %%
# 3. Write a Python program to add two numbers using variables.
a = 10
b = 5
sum = a + b
print("sum of a and b is",sum)
# Out:
# sum of a and b is 15

# %%
# 4 Write a Python program to find the area of a rectangle using variables.
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))
area = length * width
print("The area of the rectangle is:", area)
# Out:
# Enter the length of the rectangle: 10
# Enter the width of the rectangle: 20.36
# The area of the rectangle is: 203.6

# %%
# 5 Write a Python program to swap two numbers using a third variable.
a = 10
b = 22
temp = a
a = b
b = temp
print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# After swapping:
# a = 22
# b = 10

# %%
# 6 rite a Python program to calculate simple interest using variables.
s = 1000
p = 200
r = 39
si = (s * p * r) / 100
print("The simple interest is:", si)
# Out:
# The simple interest is: 78000.0

# %%
# 7 write a Python program to find the average of three numbers using variables.
a = 10
b = 230
c = 237
average = (a + b + c) / 3
print("The average of the three numbers is:", average)
# Out:
# The average of the three numbers is: 159.0

# %%
# 8 Write a Python program to demonstrate the use of a constant variable.
HP = 9.14
print("value of HP",HP)
# Out:
# value of HP 9.14

# %%
# 9 Write a Python program to use a float variable and print its value up to two decimal places.
price = 99.2334
print("price = {:.2f}".format(price))
# Out:
# price = 99.23

# %%
# 10. Write a Python program to show the use of a local variable.
def my_function():
    x = 10
    print("Inside the function:", x)

my_function()
# Out:
# Inside the function: 10
