# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita991/college/blob/master/set_2_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Hi, how may i help you ?
# I'm the chatbot to help you out..
# user1

print('HI,how may i help you?')
print("I'm chatbot to help out..")
# Out:
# HI,how may i help you?
# I'm chatbot to help out..

# %%
# user2
print('Hi,how may i help you?')
print("I'm chatbot to help out..")
# Out:
# Hi,how may i help you?
# I'm chatbot to help out..

# %%
# 1 function is a block of reusable code. wehenever there is need that
# take we call that fucnction
# on the time of function definition we give the parameters which are
# being used into the function...

# def keyword is used to define the function
#(parameters) -> def function_name(parameters):
#                    particular task
def coffee_machine(sugar, milk, beans):
 # prepare beans
 print('preparing beans..')
 # taking milk
 print('maxing coffee with the milk')
 # coffee is ready
 print('your coffee is ready...')

# calling function -> at the time of calling the function with the function
# name we pass the values at that and that values are known arguments.
coffee_machine('sugar', 'milk', 'beans')
# Out:
# preparing beans..
# maxing coffee with the milk
# your coffee is ready...

# %%
def greeting_msg():
  return 'Hello, There..this is chatbot app..'

  print(greeting_msg())

# %%
def add(a, b):
  # return keyword is used to return the value
  return a + b
# when we are calling the function this return a value..stored into the
# variable sum
#which we can use anywhere in our program
sum = add(3, 4)
print('This sum is', sum)


#(the sum is a+b)
# Out:
# This sum is 7

# %%
# wtrite a program to make a calculator [add,sub,multlication ,div] the sum is, sum

def add(num1,num2):
    return num1 + num2
def sub(num1,num2):
    return num1 - num2
def mult(num1,num2):
    return num1 * num2
def div(num1,num2):
    return num1 / num2
sum = add(2,3)
print('The sum is',sum)
sum = sub(2,3)
print('The sum is',sum)
sum = mult(2,3)
print('The sum is',sum)
sum = div(2,3)
print('The sum is',sum)
# Out:
# The sum is 5
# The sum is -1
# The sum is 6
# The sum is 0.6666666666666666

# %%
from os import MFD_HUGE_16GB
a = int(input('enter first number:'))
b = int(input('enter the second number:'))
operation = input('what operation would you want to perform ? :')
def add (a, b):
  return a + b
  def sub (a, b):
    return a - b
    def mul (a, b):
      return a * b
      def div (a, b):
        return a / b
      if operation == 'sum':
        sum = (add(a, b))
        print('The sum is',sum)
      elif operation == 'mul':
        Mul = (mul(a, b))
        print('The multiplcation is',Mul)
      else:
        print('invalid operation')
# Out:
# enter first number:20
# enter the second number:10
# what operation would you want to perform ? :sum

# %%
# positional arguments , default keyword arguments, variable lenght
# keyword argument, local and global variables , nested function

# function ?
# definition, function calling, parameter and argument, return statement
