# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita991/college/blob/master/if_else_and_nested_if_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# qus.1

num = int(input("enter number"))
if (num<0):
  print("nagative")
elif (num > 0):
    print("positive")
else:
      print("zero")
# Out:
# enter number24
# positive

# %%
# qus. 2

num = int(input("enter number"))
if(num%2==0):
     print("even")
else:
     print("odd")
# Out:
# enter number16
# even

# %%
#  qus. 3

age = int(input("enter your age"))
if(age>=18):
  print("you are eligible for voting")
else:
  print("you are not eligible for voting")
# Out:
# enter your age18
# you are eligible for voting

# %%
# qus. 4

a = int(input("1 number"))
b = int(input("2 number"))

if(a>b):
     print(f"{a} is largest number")
else:
     print(f"{b} is largest number")
# Out:
# 1 number20
# 2 number50
# 50 is largest number

# %%
# qus. 6

num = int(input("enter a number to check wheter a number is divisible by 5 and 11"))
if(num%5==0  and  num%11==0):
  print("yes it is divisible by 5 and 11")
else:
  print("not is divisible by 5 and 11")
# Out:
# enter a number to check wheter a number is divisible by 5 and 1133
# not is divisible by 5 and 11

# %%
# qus. 5
char=input("Enter char : ")
if char in'aeiou':
  print("vowel")
else:
  print("consonent")
# Out:
# Enter char : h
# consonent
# Enter char : e
# vowel

# %%
# qus.7

year = int(input("enter year"))
if(year%4==0):
  print("leap year")
else:
  print("not leap year")
# Out:
# enter year4
# leap year

# %%
# nested if-else
# qus.1

num = int(input("enter number"))
if(num>=0):
  if(num%2==0):
    print("zero")
  else:
    print("positive")
else:
  print("nagative")
# Out:
# enter number76
# zero

# %%
# qus.2

marks = int(input("enter marks"))
if(marks>=90):
  print("grade A")
elif(marks>=80):
  print("grade B")

elif(marks>=70):
  print("grade C")
elif(marks>=60):
  print("grade D")
else:
  print("fail  !!!")
# Out:
# enter marks88
# grade B

# %%
# qus.3

age = int(input("enter age"))
if(age>=13):
  if(age<=19):
    print("teenager")
  else:
    print("adult")
else:
  print("child")
# Out:
# enter age20
# adult

# %%
# qus.4
num = int(input("enter a number"))
num2= int(input("enter a number"))
num3= int(input("enter a number"))
if(num>num2 and num>num3):
  print(f"{num} is largest number")
elif(num2>num and num2>num3):
  print(f"{num2} is largest number")
else:
  print(f"{num3} is largest ")
# Out:
# enter a number44
# enter a number76
# enter a number90
# 90 is largest

# %%
# qus. 5

l = int(input("enter lenght of tringle"))
b = int(input("enter breth of  tringle"))
h = int(input("enter height of tringle"))
if(l == b == h):
   print("equilateral tringle")
elif(l == b or b == h or h == l):
   print("isosceles tringle")
else:
   print("scalene tringle")
# Out:
# enter lenght of tringle67
# enter breth of  tringle77
# enter height of tringle55
# scalene tringle
